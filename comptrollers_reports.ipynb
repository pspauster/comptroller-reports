# %% [markdown]
# <a href="https://colab.research.google.com/github/pspauster/comptroller-reports/blob/master/comptrollers_reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

cookies = {
    '_ga': 'GA1.1.735885569.1725385004',
    '_ga_7FM414V4W9': 'GS1.1.1725630511.2.0.1725630511.0.0.0',
    'visid_incap_1216935': 'y40F6a0SRQ+ZtXC9ktZqDRMNxmcAAAAAQUIPAAAAAAB2biEOTZ1fDp5XviWcoh4K',
    '_ga_GYRKWPJBCL': 'GS1.1.1741064755.2.0.1741064755.0.0.0',
    'PHPSESSID': 'jsto6s50bp2u81qreeuh8fmk3b',
    'nlbi_1216935': 'WXSXUuU4amjkz5OBq3Ux7gAAAADsutS2Kij0ncmE8sAgWt+j',
    'incap_ses_180_1216935': 'YQeRIBcAomzgVlxiT31/Ar2HyGcAAAAA2Vh2XQLYPQzeJ7nHcx9Wkg==',
    '_ga_BLHED8K050': 'GS1.1.1741195198.7.0.1741195198.0.0.0',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/json',
    'dnt': '1',
    'origin': 'https://comptroller.nyc.gov',
    'priority': 'u=1, i',
    'referer': 'https://comptroller.nyc.gov/reports/',
    'sec-ch-ua': '"Not(A:Brand";v="99", "Google Chrome";v="133", "Chromium";v="133"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'sec-gpc': '1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Mobile Safari/537.36',
    # 'cookie': '_ga=GA1.1.735885569.1725385004; _ga_7FM414V4W9=GS1.1.1725630511.2.0.1725630511.0.0.0; visid_incap_1216935=y40F6a0SRQ+ZtXC9ktZqDRMNxmcAAAAAQUIPAAAAAAB2biEOTZ1fDp5XviWcoh4K; _ga_GYRKWPJBCL=GS1.1.1741064755.2.0.1741064755.0.0.0; PHPSESSID=jsto6s50bp2u81qreeuh8fmk3b; nlbi_1216935=WXSXUuU4amjkz5OBq3Ux7gAAAADsutS2Kij0ncmE8sAgWt+j; incap_ses_180_1216935=YQeRIBcAomzgVlxiT31/Ar2HyGcAAAAA2Vh2XQLYPQzeJ7nHcx9Wkg==; _ga_BLHED8K050=GS1.1.1741195198.7.0.1741195198.0.0.0',
}

json_data = {
    'action': 'facetwp_refresh',
    'data': {
        'facets': {
            'type': [],
            'topic': [],
            'agency': [],
            'date': [],
            'search': '',
        },
        'frozen_facets': {},
        'http_params': {
            'get': {},
            'uri': 'reports',
            'url_vars': [],
        },
        'template': 'wp',
        'extras': {
            'pager': True,
            'counts': True,
            'sort': 'default',
        },
        'soft_refresh': 0,
        'is_bfcache': 1,
        'first_load': 0,
        'paged': 1,
    },
}

response = requests.post('https://comptroller.nyc.gov/reports/', cookies=cookies, headers=headers, json=json_data)

# Note: json_data will not be serialized by requests
# exactly as it was in the original request.
#data = '{"action":"facetwp_refresh","data":{"facets":{"type":[],"topic":[],"agency":[],"date":[],"search":""},"frozen_facets":{},"http_params":{"get":{},"uri":"reports","url_vars":[]},"template":"wp","extras":{"pager":true,"counts":true,"sort":"default"},"soft_refresh":0,"is_bfcache":1,"first_load":0,"paged":1}}'
#response = requests.post('https://comptroller.nyc.gov/reports/', cookies=cookies, headers=headers, data=data)

# %%
response.json()
# Out:
# {'facets': {'type': '<div class="facetwp-checkbox" data-value="annual"><span class="facetwp-display-value">Annual</span><span class="facetwp-counter">(23)</span></div><div class="facetwp-depth"><div class="facetwp-checkbox" data-value="annual-audit-report"><span class="facetwp-display-value">Annual Audit Report</span><span class="facetwp-counter">(1)</span></div><div class="facetwp-checkbox" data-value="annual-contracts-report"><span class="facetwp-display-value">Annual Contracts Report</span><span class="facetwp-counter">(1)</span></div><div class="facetwp-checkbox" data-value="capital-debt-and-obligations"><span class="facetwp-display-value">Capital Debt and Obligations</span><span class="facetwp-counter">(2)</span></div><div class="facetwp-checkbox" data-value="climate-report"><span class="facetwp-display-value">Climate Report</span><span class="facetwp-counter">(6)</span></div><div class="facetwp-checkbox" data-value="mwbe-procurement"><span class="facetwp-display-value">MWBE Procurement</span><span class="facetwp-counter">(2)</span></div><div class="facetwp-checkbox" data-value="shareowner-initiatives"><span class="facetwp-display-value">Shareowner Initiatives</span><span class="facetwp-counter">(1)</span></div><div class="facetwp-checkbox" data-value="state-of-the-economy"><span class="facetwp-display-value">State of the Economy</span><span class="facetwp-counter">(2)</span></div></div><div class="facetwp-checkbox" data-value="audit"><span class="facetwp-display-value">Audit &amp; Investigation</span><span class="facetwp-counter">(1441)</span></div><div class="facetwp-checkbox" data-value="budget"><span class="facetwp-display-value">Budget</span><span class="facetwp-counter">(179)</span></div><div class="facetwp-depth"><div class="facetwp-checkbox" data-value="cash-projection"><span class="facetwp-display-value">Cash Projection</span><span class="facetwp-counter">(6)</span></div></div><div class="facetwp-checkbox" data-value="contracts"><span class="facetwp-display-value">Contracts</span><span class="facetwp-counter">(6)</span></div><div class="facetwp-checkbox" data-value="economic"><span class="facetwp-display-value">Economic</span><span class="facetwp-counter">(43)</span></div><div class="facetwp-checkbox" data-value="financial-reporting"><span class="facetwp-display-value">Financial Reporting</span><span class="facetwp-counter">(84)</span></div><div class="facetwp-checkbox" data-value="fiscal-notes"><span class="facetwp-display-value">Fiscal Notes</span><span class="facetwp-counter">(6)</span></div><div class="facetwp-checkbox" data-value="interactive"><span class="facetwp-display-value">Interactive</span><span class="facetwp-counter">(16)</span></div><div class="facetwp-checkbox" data-value="letters"><span class="facetwp-display-value">Letters</span><span class="facetwp-counter">(37)</span></div><div class="facetwp-checkbox" data-value="policy"><span class="facetwp-display-value">Policy</span><span class="facetwp-counter">(191)</span></div><div class="facetwp-checkbox" data-value="spotlight"><span class="facetwp-display-value">Spotlight</span><span class="facetwp-counter">(24)</span></div>',
#   'topic': '<div class="facetwp-checkbox" data-value="budget-financial"><span class="facetwp-display-value">Budget/Financial</span><span class="facetwp-counter">(161)</span></div><div class="facetwp-checkbox" data-value="workforce"><span class="facetwp-display-value">Workforce</span><span class="facetwp-counter">(50)</span></div><div class="facetwp-checkbox" data-value="housing"><span class="facetwp-display-value">Housing</span><span class="facetwp-counter">(44)</span></div><div class="facetwp-checkbox" data-value="infrastructure"><span class="facetwp-display-value">Infrastructure</span><span class="facetwp-counter">(40)</span></div><div class="facetwp-checkbox" data-value="education"><span class="facetwp-display-value">Education</span><span class="facetwp-counter">(36)</span></div><div class="facetwp-checkbox" data-value="health"><span class="facetwp-display-value">Health</span><span class="facetwp-counter">(25)</span></div><div class="facetwp-checkbox" data-value="transportation"><span class="facetwp-display-value">Transportation</span><span class="facetwp-counter">(25)</span></div><div class="facetwp-checkbox" data-value="government-transparency"><span class="facetwp-display-value">Government Transparency</span><span class="facetwp-counter">(24)</span></div><div class="facetwp-checkbox" data-value="sustainability"><span class="facetwp-display-value">Climate and Sustainability</span><span class="facetwp-counter">(21)</span></div><div class="facetwp-checkbox" data-value="public-safety"><span class="facetwp-display-value">Public Safety</span><span class="facetwp-counter">(19)</span></div><div class="facetwp-checkbox" data-value="civil-rights"><span class="facetwp-display-value">Civil Rights</span><span class="facetwp-counter">(14)</span></div><div class="facetwp-checkbox" data-value="children"><span class="facetwp-display-value">Children</span><span class="facetwp-counter">(8)</span></div><div class="facetwp-checkbox" data-value="immigration"><span class="facetwp-display-value">Immigration</span><span class="facetwp-counter">(6)</span></div><div class="facetwp-checkbox" data-value="administration"><span class="facetwp-display-value">Administration</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-checkbox" data-value="pensions"><span class="facetwp-display-value">Pensions</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-checkbox" data-value="investing-in-neighborhoods"><span class="facetwp-display-value">Investing in Neighborhoods</span><span class="facetwp-counter">(1)</span></div>',
#   'agency': '<div class="facetwp-checkbox" data-value="actuary-office-of-the"><span class="facetwp-display-value">Actuary, Office Of The</span><span class="facetwp-counter">(6)</span></div><div class="facetwp-checkbox" data-value="administration-for-childrens-services"><span class="facetwp-display-value">Administration For Children&#039;s Services</span><span class="facetwp-counter">(54)</span></div><div class="facetwp-checkbox" data-value="administrative-tax-appeals-office-of"><span class="facetwp-display-value">Administrative Tax Appeals, Office of</span><span class="facetwp-counter">(1)</span></div><div class="facetwp-checkbox" data-value="aging-department-for-the"><span class="facetwp-display-value">Aging, Department For The</span><span class="facetwp-counter">(20)</span></div><div class="facetwp-checkbox" data-value="borough-of-manhattan-community-college-of-cuny"><span class="facetwp-display-value">Borough of Manhattan Community College of CUNY</span><span class="facetwp-counter">(1)</span></div><div class="facetwp-checkbox" data-value="borough-president-bronx"><span class="facetwp-display-value">Borough President-Bronx</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-checkbox" data-value="borough-president-brooklyn"><span class="facetwp-display-value">Borough President-Brooklyn</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-checkbox" data-value="borough-president-manhattan"><span class="facetwp-display-value">Borough President-Manhattan</span><span class="facetwp-counter">(6)</span></div><div class="facetwp-checkbox" data-value="borough-president-queens"><span class="facetwp-display-value">Borough President-Queens</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-checkbox" data-value="borough-president-staten-island"><span class="facetwp-display-value">Borough President-Staten Island</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-checkbox" data-value="buildings-department-of"><span class="facetwp-display-value">Buildings, Department Of</span><span class="facetwp-counter">(25)</span></div><div class="facetwp-checkbox" data-value="business-improvement-districts"><span class="facetwp-display-value">Business Improvement Districts</span><span class="facetwp-counter">(2)</span></div><div class="facetwp-checkbox" data-value="business-integrity-commission"><span class="facetwp-display-value">Business Integrity Commission</span><span class="facetwp-counter">(8)</span></div><div class="facetwp-checkbox" data-value="business-services-department-of"><span class="facetwp-display-value">Business Services, Department Of</span><span class="facetwp-counter">(9)</span></div><div class="facetwp-checkbox" data-value="campaign-finance-board"><span class="facetwp-display-value">Campaign Finance Board</span><span class="facetwp-counter">(4)</span></div><div class="facetwp-checkbox" data-value="city-clerk"><span class="facetwp-display-value">City Clerk</span><span class="facetwp-counter">(7)</span></div><div class="facetwp-checkbox" data-value="city-council"><span class="facetwp-display-value">City Council</span><span class="facetwp-counter">(1)</span></div><div class="facetwp-checkbox" data-value="city-planning-department-of"><span class="facetwp-display-value">City Planning, Department Of</span><span class="facetwp-counter">(11)</span></div><div class="facetwp-checkbox" data-value="city-university-of-new-york"><span class="facetwp-display-value">City University Of New York</span><span class="facetwp-counter">(9)</span></div><div class="facetwp-checkbox" data-value="citywide-administrative-services-department-of"><span class="facetwp-display-value">Citywide Administrative Services, Department Of</span><span class="facetwp-counter">(32)</span></div><div class="facetwp-checkbox" data-value="civil-service-commission"><span class="facetwp-display-value">Civil Service Commission</span><span class="facetwp-counter">(5)</span></div><div class="facetwp-chec ...
#   'date': '<input type="text" class="facetwp-date facetwp-date-min" data-empty="No start dates" value="" placeholder="Start date" /><input type="text" class="facetwp-date facetwp-date-max" data-empty="No end dates" value="" placeholder="End date" />',
#   'search': '<span class="facetwp-input-wrap"><i class="facetwp-icon"></i><input type="text" class="facetwp-search" value="" placeholder="Press Enter to Search" autocomplete="off" /></span>'},
#  'template': '<div class="alert alert-primary m-0 p-2 text-center rounded-0 border-0 dontUseIE" role="alert">\r\n  <div class="container">Microsoft Internet Explorer is no longer a supported browser on NYC Comptroller’s website.<br>\r\n    Please use Microsoft Edge, Google Chrome, Apple Safari or Mozilla Firefox.</div>\r\n</div>\r\n<header id="header" class="mb-5" role="banner">\r\n  <div id="navWrapper" class="container">\r\n    <div id="miniNav" class="pt-3 text-end">\r\n      <ul class="list-inline">\r\n        <li class="list-inline-item">\r\n          <div id="word-container">\r\n            <div class="word w1">Español</div>\r\n            <div class="word w2">繁體中文</div>\r\n            <div class="word w3">简体中文</div>\r\n            <div class="word w4">Русский</div>\r\n            <div class="word w5">한 국 어</div>\r\n            <div class="word w6">Kreyòl ayisyen</div>\r\n            <div class="word w7">Italiano</div>\r\n          </div>\r\n          <i class="icofont-caret-right text-white"></i> </li>\r\n        <li class="list-inline-item" id="languageTab"> <div class="gtranslate_wrapper" id="gt-wrapper-13364918"></div> </li>\r\n        <li class="list-inline-item d-none d-sm-inline-block"> <a href="https://comptroller.nyc.gov/newsletters" class="btn btn-link text-white">Join Mailing List</a> </li>\r\n        <li class="list-inline-item d-none d-md-inline-block">\r\n          <ul class="list-inline">\r\n                        <li class="list-inline-item"> <a href="https://twitter.com/NYCComptroller" rel="noopener" target="_blank" title="Twitter"> <i class="fa-brands fa-twitter"></i> </a> </li>\r\n                                                <li class="list-inline-item"> <a href="https://www.facebook.com/ComptrollerNYC" rel="noopener" target="_blank" title="Facebook"> <i class="icofont-facebook"></i> </a> </li>\r\n                                    <li class="list-inline-item"> <a href="https://www.instagram.com/NYCComptroller/" rel="noopener" target="_blank" title="Instagram"> <i class="icofont-instagram"></i> </a> </li>\r\n                                    <li class="list-inline-item"> <a href="https://www.youtube.com/c/nyccomptroller" rel="noopener" target="_blank" title="YouTube"> <i class="icofont-youtube"></i> </a> </li>\r\n                                    <li class="list-inline-item"> <a href="https://www.flickr.com/photos/nyccomptroller/" rel="noopener" target="_blank" title="Flickr"> <i class="icofont-flikr"></i> </a> </li>\r\n                      </ul>\r\n        </li>\r\n      </ul>\r\n    </div>\r\n    <nav class="navbar navbar-expand-lg navbar-light">\r\n      <div class="container g-0"> <a class="navbar-brand" title="New York City Comptroller Brad Lander" href="https://comptroller.nyc.gov/"> <img src="https://comptroller.nyc.gov/wp-content/uploads/2022/01/Brad_Lander_Logo_white_sm.png" alt="New York City Comptroller Brad Lander"/> </a>\r\n        <button class="navbar-toggler border-light" type="button" data-bs-toggle="collapse" data-bs-target="#navbarContent" aria-controls="navbarContent" aria-expanded="false" aria-label="Toggle navigation"> <i class="icofont-navigation-menu text-white"></i> </button>\r\n        <div class="collapse navbar-collapse" id="navbarContent">\r\n          <ul class="navbar-nav float-lg-end">\r\n            <li class="nav-item dropdown d-none d-lg-block"> <a class="nav-link dropdown-toggle displayFont" href="https://comptroller.nyc.gov/about/" id="aboutDropdown" role="button" aria-expanded="false">About</a>\r\n              <div class="dropdown-menu shadow p-0 ps-lg-3 overflow-hidden" aria-labelledby="aboutDropdown">\r\n                <ul class="row list-unstyled">\r\n                  <li id="menu-item-81777" class="border-end col p-3 menu-item menu-item-type-post_type menu-item-object-page"> <a href="https://comptroller.nyc.gov/about/leadership-team/" class="h5 mb-3 text-decoration-none">Leadership Team</a>\r\n                    <p class="d-none d-md-block m-0">Le ...
#  'settings': {'debug': 'Enable debug mode in [Settings > FacetWP > Settings]',
#   'pager': {'page': 1,
#    'per_page': 16,
#    'total_rows': 1938,
#    'total_rows_unfiltered': 1938,
#    'total_pages': 122},
#   'num_choices': {'type': 19, 'topic': 16, 'agency': 110},
#   'labels': {'type': 'Type',
#    'topic': 'Topic',
#    'agency': 'Agency',
#    'date': 'Date',
#    'search': 'Search'},
#   'type': {'show_expanded': 'no'},
#   'topic': {'show_expanded': 'no'},
#   'agency': {'show_expanded': 'no'},
#   'date': {'locale': '',
#    'format': '',
#    'fields': 'both',
#    'range': {'min': {'minDate': '1998-10-01', 'maxDate': '2025-03-03'},
#     'max': {'minDate': '1998-10-01', 'maxDate': '2025-03-03'}}},
#   'search': {'auto_refresh': 'no'}},
#  'pager': '<div class="facetwp-pager"><a class="facetwp-page first active" data-page="1">1</a><a class="facetwp-page" data-page="2">2</a><a class="facetwp-page" data-page="3">3</a><a class="facetwp-page dots">…</a><a class="facetwp-page last" data-page="122">122</a><a class="facetwp-page next" data-page="2">&gt;&gt;</a></div>',
#  'counts': 'Showing: 1-16 of 1938 results',
#  'sort': '<select class="facetwp-sort-select"><option value="default">Sort by</option><option value="title_asc">Title (A-Z)</option><option value="title_desc">Title (Z-A)</option><option value="date_desc">Date (Newest)</option><option value="date_asc">Date (Oldest)</option></select>'}
